# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
dati=pd.read_csv("preproc_122013_230654_cam.csv", index_col="frame")

# %%
dati.head()
# Out:
#              F1        F2        F3        F4        F5        F6        F7  \
# frame
# 96     0.093232  0.195913  0.318482  0.415069  0.437812  0.478112  0.439322
# 97     0.195913  0.318482  0.415069  0.437812  0.478112  0.439322  0.428315
# 98     0.318482  0.415069  0.437812  0.478112  0.439322  0.428315  0.413761
# 99     0.415069  0.437812  0.478112  0.439322  0.428315  0.413761  0.387997
# 100    0.437812  0.478112  0.439322  0.428315  0.413761  0.387997  0.412974
#
#              F8        F9       F10       F11       F12       F13  blink
# frame
# 96     0.428315  0.413761  0.387997  0.412974  0.458515  0.472926    0.0
# 97     0.413761  0.387997  0.412974  0.458515  0.472926  0.473466    0.0
# 98     0.387997  0.412974  0.458515  0.472926  0.473466  0.403091    0.0
# 99     0.412974  0.458515  0.472926  0.473466  0.403091  0.449194    0.0
# 100    0.458515  0.472926  0.473466  0.403091  0.449194  0.415271    0.0

# %%
dati_blink=dati[dati.blink==1]

# %%
dati_blink.shape[0]
# Out:
# 448

# %%
si_b=dati_blink.iloc[np.random.choice(dati_blink.shape[0], size=300,replace=False)]

# %%
si_b.head(10)
# Out:
#              F1        F2        F3        F4        F5        F6        F7  \
# frame
# 3958   0.351512  0.251979  0.341991  0.390450  0.438781  0.514783  0.597432
# 3471   0.233662  0.156086  0.212807  0.324025  0.488236  0.585040  0.707018
# 276    0.101212  0.218020  0.162899  0.315211  0.290945  0.316230  0.306158
# 1620   0.821792  0.774755  0.415277  0.385275  0.341145  0.373034  0.489447
# 3062   0.777383  0.754330  0.770348  0.802846  0.778841  0.814382  0.797591
# 3070   0.802294  0.545257  0.281461  0.391683  0.418241  0.546645  0.630583
# 3948   0.792514  0.742851  0.741957  0.741904  0.791007  0.791007  0.791007
# 4957   0.756497  0.850004  0.810367  0.789464  0.780960  0.810999  0.826346
# 361    0.245943  0.217201  0.154929  0.186314  0.149982  0.167357  0.118790
# 935    0.622993  0.629654  0.676638  0.639927  0.603308  0.627753  0.631093
#
#              F8        F9       F10       F11       F12       F13  blink
# frame
# ...

# %%
dati_nob=dati_blik=dati[dati.blink==0]
no_b=dati_nob.iloc[np.random.choice(dati_nob.shape[0], size=300,replace=False)]

# %%
result=pd.concat([no_b,si_b])
result
# Out:
#              F1        F2        F3        F4        F5        F6        F7  \
# frame
# 741    0.641548  0.622961  0.567697  0.622961  0.583196  0.571352  0.657246
# 892    0.597583  0.631924  0.585538  0.640064  0.638628  0.560442  0.603730
# 4330   0.744455  0.713800  0.748664  0.741575  0.755752  0.761547  0.713800
# 3092   0.798117  0.773314  0.772138  0.752322  0.797085  0.739357  0.789513
# 225    0.377342  0.399330  0.412049  0.415069  0.402954  0.377404  0.392539
# 3424   0.740857  0.760533  0.758451  0.812844  0.736779  0.808143  0.789706
# 2947   0.748730  0.752483  0.754285  0.779346  0.802294  0.784439  0.777232
# 4276   0.646166  0.660852  0.702879  0.753407  0.731777  0.705181  0.701653
# 5117   0.764516  0.759549  0.727578  0.730085  0.687926  0.759549  0.757730
# 4298   0.730594  0.777582  0.712513  0.758572  0.738597  0.790696  0.730478
# 5251   0.784535  0.779346  0.773877  0.797339  0.806234  0.795096  0.779816
# ...

# %%
result.to_csv("balanced_preproc_122013_230654_cam.csv", index=True, header=True)
