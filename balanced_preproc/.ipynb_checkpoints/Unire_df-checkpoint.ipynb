# %%
import pandas as pd
import numpy as np

# %%
video_1=pd.read_csv("balanced_preproc_122013_223310_cam.csv", sep=",", index_col="frame")
video_2=pd.read_csv("balanced_preproc_122013_224532_cam.csv", sep=",", index_col="frame")
video_3=pd.read_csv("balanced_preproc_122013_230103_cam.csv", sep=",", index_col="frame")
video_4=pd.read_csv("balanced_preproc_122013_230654_cam.csv", sep=",", index_col="frame")
video_5=pd.read_csv("balanced_preproc_122013_151644_cam.csv", sep=",", index_col="frame")
video_6=pd.read_csv("balanced_preproc_122013_152435_cam.csv", sep=",", index_col="frame")
video_7=pd.read_csv("balanced_preproc_122013_153916_cam.csv", sep=",", index_col="frame")
video_8=pd.read_csv("balanced_preproc_122013_154548_cam.csv", sep=",", index_col="frame")

dati_fin=pd.concat([video_1,video_2,video_3,video_4,video_5,video_6,video_7,video_8])
dati_fin[dati_fin.blink==1].shape[0]
# Out:
# 2400

# %%
dati_fin.to_csv("balanced_preproc_all.csv", index=True, header=True)

# %%
dati_fin[dati_fin.blink==0].shape[0]
# Out:
# 2400
